# %%
import pandas as pd
import requests
import time

# %%
url = 'https://api.coincap.io/v2/assets?'

response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
asset = response.json()
asset
# Out:
# {'data': [{'id': 'bitcoin',
#    'rank': '1',
#    'symbol': 'BTC',
#    'name': 'Bitcoin',
#    'supply': '19720181.0000000000000000',
#    'maxSupply': '21000000.0000000000000000',
#    'marketCapUsd': '1153466749548.5723898697876007',
#    'volumeUsd24Hr': '8109531729.7801531121444823',
#    'priceUsd': '58491.6918129997077547',
#    'changePercent24Hr': '2.3103663218956367',
#    'vwap24Hr': '57918.7449900732985109',
#    'explorer': 'https://blockchain.info/'},
#   {'id': 'ethereum',
#    'rank': '2',
#    'symbol': 'ETH',
#    'name': 'Ethereum',
#    'supply': '120213385.0061942200000000',
#    'maxSupply': None,
#    'marketCapUsd': '379933886851.8744251798290933',
#    'volumeUsd24Hr': '5678039488.3830724974432363',
#    'priceUsd': '3160.4957038045107829',
#    'changePercent24Hr': '2.9235182533314477',
#    'vwap24Hr': '3126.9823791998513305',
#    'explorer': 'https://etherscan.io/'},
#   {'id': 'tether',
#    'rank': '3',
#    'symbol': 'USDT',
#    'name': 'Tether',
# ...

# %%
df = pd.DataFrame(asset['data'])
df
# Out:
#               id rank symbol        name                         supply  \
# 0        bitcoin    1    BTC     Bitcoin      19720181.0000000000000000
# 1       ethereum    2    ETH    Ethereum     120213385.0061942200000000
# 2         tether    3   USDT      Tether  112417360493.7834500000000000
# 3   binance-coin    4    BNB         BNB     166801148.0000000000000000
# 4         solana    5    SOL      Solana     463950848.0351124400000000
# ..           ...  ...    ...         ...                            ...
# 95          just   96    JST        JUST    9900000000.0000000000000000
# 96      illuvium   97    ILV    Illuvium       4474125.6968716300000000
# 97          celo   98   CELO        Celo     542396781.0000000000000000
# 98     superfarm   99  SUPER  SuperVerse     487776093.4169172600000000
# 99          aelf  100    ELF        aelf     731609229.9091900000000000
#
#                       maxSupply                    marketCapUsd  \
# ...
